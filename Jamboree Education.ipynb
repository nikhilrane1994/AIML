# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
sns.color_palette("pastel")
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %% [markdown]
# # Define Problem Statement and perform Exploratory Data Analysis

# %%
df=pd.read_csv("C:\\Users\\siddhika.pawar\\Desktop\\Data science\\Data_set\\Jamboree_Admission.csv")
df.head()
df.drop(columns='Serial No.',inplace=True)
df.rename(columns={"Chance of Admit ": "Chance of Admit"},inplace=True)
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
#      Chance of Admit
# 0               0.92
# 1               0.76
# ...

# %%
df.isna().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP       LOR   \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean   316.472000   107.192000           3.114000    3.374000    3.48400
# std     11.295148     6.081868           1.143512    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research  Chance of Admit
# count  500.000000  500.000000        500.00000
# mean     8.576440    0.560000          0.72174
# std      0.604813    0.496884          0.14114
# min      6.800000    0.000000          0.34000
# 25%      8.127500    0.000000          0.63000
# ...

# %%
fig,axes=plt.subplots(3,2,figsize=(16,8))
sns.color_palette("pastel")
sns.histplot(df['GRE Score'],ax=axes[(0,0)],bins=20,palette=['red'])
sns.histplot(df['TOEFL Score'],ax=axes[(0,1)],bins=20)
sns.histplot(df['CGPA'],ax=axes[(1,0)],bins=20)
sns.countplot(df['University Rating'],ax=axes[(2,1)])
sns.countplot(df['Research'],ax=axes[(2,0)])
# Out:
# C:\Users\siddhika.pawar\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\siddhika.pawar\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Research', ylabel='count'>

# %%
data = np.random.random(size=(8, 8))
df1 = pd.DataFrame(data, columns = df.columns)
df1.boxplot()
plt.show()

# %% [markdown]
# ## Observation
#
# ### Most  of the students having  GRE score is In between 310 to 320
# ### Most  of the students having  TOEFL score is In between 100 to 115
# ### Most  of the students having  CGPA  is In between 310 to 320 7.9 to  9.5
# ### Most of the univerties L:isted having ranking in between 3 to 3.1
# ### Some One submitted research paper maximizes their chance for admission
# ### Their is not much varaiation between max value and median of data "Outliers" are not presenrt

# %%
df.corr()
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)

# %%
fig,axes=plt.subplots(3,figsize=(8,8))
sns.color_palette("pastel")
sns.scatterplot(data=df,x=df['GRE Score'],y=df['Chance of Admit'],ax=axes[0])
sns.scatterplot(data=df,x=df['TOEFL Score'],y=df['Chance of Admit'],ax=axes[1])
sns.scatterplot(data=df,x=df['CGPA'],y=df['Chance of Admit'],ax=axes[2])
# Out:
# <AxesSubplot:xlabel='CGPA', ylabel='Chance of Admit'>

# %% [markdown]
# ## Observation
#
# ### Chance of admit in universiy is higher if we could get good score in  CGPA,GRE and TOFEL in order

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # Observation
# ### No outliers present, no duplication in data

# %%
df.head()
df.shape
# Out:
# (500, 8)

# %%
# Statmodels implementation of Linear regression 
import statsmodels.api as sm
# Lets scale the data, standardization 
from sklearn.preprocessing import StandardScaler

#X = df[df.columns.drop('Chance of Admit')]
X=df.drop(['Chance of Admit'],axis=1)
Y = df["Chance of Admit"] 
sc = StandardScaler()
cols = X.columns
X[cols] = sc.fit_transform(X[cols])

X_sm = sm.add_constant(X)  #Statmodels default is without intercept, to add intercept we need to add constant 
sm_model = sm.OLS(Y, X_sm).fit()
print(sm_model)
print(sm_model.summary())

print("coefficient of features",sm_model.params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 7>()
#       4 from sklearn.preprocessing import StandardScaler
#       6 #X = df[df.columns.drop('Chance of Admit')]
# ----> 7 X=df.drop(['Chance of Admit'],axis=1)
#       8 Y = df["Chance of Admit"]
#       9 sc = StandardScaler()
#
# NameError: name 'df' is not defined

# %%
#Display model coefficients with column names
print("coefficient of features",sm_model.params)
# Out:
# coefficient of features const                0.721740
# GRE Score            0.020971
# TOEFL Score          0.016878
# University Rating    0.006787
# SOP                  0.001570
# LOR                  0.015586
# CGPA                 0.071529
# Research             0.012066
# dtype: float64

# %%
print(X_sm.shape)
# Out:
# (500, 8)

# %%
#Multicollinearity check by VIF score (variables are dropped one-by-one till none has VIF>5) (10 Points)
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
X_t = X
vif['Features'] = X_t.columns
vif['VIF'] = [variance_inflation_factor(X_t.values, i) for i in range(X_t.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#             Features   VIF
# 5               CGPA  4.78
# 0          GRE Score  4.46
# 1        TOEFL Score  3.90
# 3                SOP  2.84
# 2  University Rating  2.62
# 4               LOR   2.03
# 6           Research  1.49

# %%
#The mean of residuals is nearly zero

# %%
# Linearity of variables (no pattern in the residual plot) (10 Points)
#The mean of residuals is nearly zero (10 Points)

Y_hat= sm_model.predict(X_sm)

errors = Y_hat - Y 
import seaborn as sns

sns.kdeplot(errors)
plt.xlabel(" Residuals")
plt.title("Histogram of residuals")
# Out:
# Text(0.5, 1.0, 'Histogram of residuals')

# %%
#Test for Homoscedasticity (10 Points)
sns.scatterplot(Y_hat,errors)
plt.xlabel("predicted Selling price")
plt.ylabel("Residuals")
plt.title("Predicted values vs Residuals")
# Out:
# C:\Users\siddhika.pawar\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Predicted values vs Residuals')

# %% [markdown]
# # observation=
# heteroskedasticity exists in our data
# There is outliers present in the dataset

# %%
#Metrics checked - MAE, RMSE, R2, Adj R2
print(sm_model.summary())
# RMSE
RMSE=(np.sum(np.square(Y_hat-Y)/len(Y)))**0.5
RMSE
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Chance of Admit   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     324.4
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):          8.21e-180
# Time:                        20:47:05   Log-Likelihood:                 701.38
# No. Observations:                 500   AIC:                            -1387.
# Df Residuals:                     492   BIC:                            -1353.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 0.7217      0.003    269.039      0.000       0.716       0.727
# ...

# %%
# Ridge
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt
rr = Ridge(alpha=0.01)
rr.fit(X_sm, Y) 
pred_train_rr= rr.predict(X_sm)
print(np.sqrt(mean_squared_error(Y,pred_train_rr)))
print(r2_score(Y, pred_train_rr))
# Out:
# 0.05950420883092595
# 0.8219007391989234

# %%
# Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt
rr = Lasso(alpha=0.01)
rr.fit(X_sm, Y) 
pred_train_rr= rr.predict(X_sm)
print(np.sqrt(mean_squared_error(Y,pred_train_rr)))
print(r2_score(Y, pred_train_rr))
# Out:
# 0.06085107881273811
# 0.8137469853699414
